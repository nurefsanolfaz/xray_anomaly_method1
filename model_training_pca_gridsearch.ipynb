# %%
# 📁 model_training_pca_gridsearch.ipynb
# Dataset1 HOG + SVM + PCA kombinasyonu icin hiperparametre optimizasyonu

import os
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from src.method1.evaluate import evaluate_model
import joblib
import sys

# Proje köküne geç
proj_root = "/Users/nurefsanolfaz/yap470_project/xray_anomaly_method1"
os.chdir(proj_root)
sys.path.insert(0, proj_root)

print("Çalışma dizini:", os.getcwd())

# === Dataset1 veya Dataset2'yi sec ===
FEATURE_DIR = "features/dataset1/hog"  # veya "features/dataset2/hog"
MODEL_SAVE_PATH = "models/dataset1/gridsearch_best_svm.pkl"  # uygun klasorle degistir

# === Ozellikleri yukle ===
X_train = np.load(os.path.join(FEATURE_DIR, "X_train.npy"))
y_train = np.load(os.path.join(FEATURE_DIR, "y_train.npy"))
X_val   = np.load(os.path.join(FEATURE_DIR, "X_val.npy"))
y_val   = np.load(os.path.join(FEATURE_DIR, "y_val.npy"))
X_test  = np.load(os.path.join(FEATURE_DIR, "X_test.npy"))
y_test  = np.load(os.path.join(FEATURE_DIR, "y_test.npy"))

# === Pipeline tanimi ===
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA()),
    ('model', SVC())
])

# === Hiperparametre araligi ===
param_grid = {
    'pca__n_components': [100, 200, 300],
    'model__C': [0.1, 1, 10],
    'model__kernel': ['rbf', 'linear'],
    'model__gamma': ['scale', 'auto']
}

# === GridSearchCV ===
grid = GridSearchCV(pipe, param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)
grid.fit(X_train, y_train)

# === En iyi sonuc ===
print("\n[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

# === Test seti uzerinde degerlendirme ===
best_model = grid.best_estimator_
evaluate_model(best_model, X_train, y_train, X_val, y_val, X_test, y_test)

# === Modeli kaydet ===
os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)
joblib.dump(best_model, MODEL_SAVE_PATH)
print(f"\n[INFO] Model kaydedildi: {MODEL_SAVE_PATH}")
# Out:
# Çalışma dizini: /Users/nurefsanolfaz/yap470_project/xray_anomaly_method1
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   9.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   9.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   9.8s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  13.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  13.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  13.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=   5.7s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=   5.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  15.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  16.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=   5.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  10.7s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   6.7s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   8.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   8.9s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=  10.8s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=  11.7s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=  11.0s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   8.7s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   8.9s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   8.8s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=  11.0s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=   4.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=   4.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=   9.9s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=  10.6s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=   4.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   6.0s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   6.6s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   7.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=  14.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=  15.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=  15.1s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   5.9s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.0s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=   9.7s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=  10.1s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=  10.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   9.2s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   9.7s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   8.8s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=   9.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  11.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   6.2s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  11.8s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  12.1s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   4.9s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=  10.2s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   5.6s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=  11.8s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   8.0s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=   9.7s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   8.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   9.0s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=  10.6s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=  10.6s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=  11.5s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=  11.1s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=   8.7s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=  11.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   4.5s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=  10.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=   7.2s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=  14.8s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=  14.5s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=  14.9s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   7.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   8.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.2s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.2s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=  10.7s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=  11.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=   9.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   8.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   8.2s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   9.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  12.8s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   8.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  12.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  13.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   5.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=200; total time=   5.8s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=   7.1s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   6.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=   7.8s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=300; total time=   8.6s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   5.9s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=100; total time=   6.2s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=   8.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=   8.0s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=200; total time=   9.3s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=  10.5s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=   9.7s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=300; total time=   9.9s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   4.2s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   2.8s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=200; total time=   3.1s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=   4.2s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=   4.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=300; total time=   4.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=  51.9s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time=  52.1s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=  34.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=100; total time= 1.1min
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=  35.1s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=100; total time=  45.2s
#
# [INFO] En iyi skor: 0.9874837040792639
# [INFO] En iyi parametreler: {'model__C': 10, 'model__gamma': 'scale', 'model__kernel': 'rbf', 'pca__n_components': 300}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 0.8125
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.99      0.38      0.55       234
#    PNEUMONIA       0.73      1.00      0.84       390
#
#     accuracy                           0.77       624
#    macro avg       0.86      0.69      0.70       624
# weighted avg       0.83      0.77      0.73       624
#
#
# [INFO] Model kaydedildi: models/dataset1/gridsearch_best_svm.pkl

# %%
# Dataset1'de Haralick + SVM + PCA + class_weight=balanced icin hiperparametre optimizasyonu


# === Dataset1 icin Haralick ozelliklerini yukle ===
FEATURE_DIR = "features/dataset1/haralick"
MODEL_SAVE_PATH = "models/dataset1/gridsearch_haralick_svm_balanced.pkl"

X_train = np.load(os.path.join(FEATURE_DIR, "X_train.npy"))
y_train = np.load(os.path.join(FEATURE_DIR, "y_train.npy"))
X_val   = np.load(os.path.join(FEATURE_DIR, "X_val.npy"))
y_val   = np.load(os.path.join(FEATURE_DIR, "y_val.npy"))
X_test  = np.load(os.path.join(FEATURE_DIR, "X_test.npy"))
y_test  = np.load(os.path.join(FEATURE_DIR, "y_test.npy"))

# === Pipeline tanimi ===
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA()),
    ('model', SVC(class_weight='balanced'))  # balanced eklendi
])

# === Hiperparametre araligi ===
param_grid = {
    'pca__n_components': [10, 13],  # Haralick ozellikleri dusuk boyutlu oldugu icin
    'model__C': [0.1, 1, 10],
    'model__kernel': ['rbf', 'linear'],
    'model__gamma': ['scale', 'auto']
}

# === GridSearchCV ===
grid = GridSearchCV(pipe, param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)
grid.fit(X_train, y_train)

# === En iyi sonuc ===
print("\n[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

# === Test seti uzerinde degerlendirme ===
best_model = grid.best_estimator_
evaluate_model(best_model, X_train, y_train, X_val, y_val, X_test, y_test)

# === Modeli kaydet ===
os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)
joblib.dump(best_model, MODEL_SAVE_PATH)
print(f"\n[INFO] Model kaydedildi: {MODEL_SAVE_PATH}")
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.2s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.3s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.8s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.7s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.9s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.7s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.7s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.3s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.6s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.6s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.7s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.6s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.6s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.7s
#
# [INFO] En iyi skor: 0.9166438433881612
# [INFO] En iyi parametreler: {'model__C': 10, 'model__gamma': 'scale', 'model__kernel': 'rbf', 'pca__n_components': 13}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 0.5000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.77      0.61      0.68       234
#    PNEUMONIA       0.79      0.89      0.84       390
#
#     accuracy                           0.78       624
#    macro avg       0.78      0.75      0.76       624
# weighted avg       0.78      0.78      0.78       624
#
#
# [INFO] Model kaydedildi: models/dataset1/gridsearch_haralick_svm_balanced.pkl

# %%
# Dataset1'de Haralick + SVM + PCA + class_weight=balanced + 5-fold CV icin hiperparametre optimizasyonu

from sklearn.model_selection import StratifiedKFold


# === Dataset1 icin Haralick ozelliklerini yukle ===
FEATURE_DIR = "features/dataset1/haralick"
MODEL_SAVE_PATH = "models/dataset1/gridsearch_haralick_svm_balanced_5fold.pkl"

X_train = np.load(os.path.join(FEATURE_DIR, "X_train.npy"))
y_train = np.load(os.path.join(FEATURE_DIR, "y_train.npy"))
X_val   = np.load(os.path.join(FEATURE_DIR, "X_val.npy"))
y_val   = np.load(os.path.join(FEATURE_DIR, "y_val.npy"))
X_test  = np.load(os.path.join(FEATURE_DIR, "X_test.npy"))
y_test  = np.load(os.path.join(FEATURE_DIR, "y_test.npy"))

# === Train + Val birlestir ===
X_combined = np.concatenate([X_train, X_val], axis=0)
y_combined = np.concatenate([y_train, y_val], axis=0)

# === Pipeline tanimi ===
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA()),
    ('model', SVC(class_weight='balanced'))
])

# === Hiperparametre araligi ===
param_grid = {
    'pca__n_components': [10, 13],
    'model__C': [0.1, 1, 10],
    'model__kernel': ['rbf', 'linear'],
    'model__gamma': ['scale', 'auto']
}

# === Stratified 5-fold Cross Validation ===
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(pipe, param_grid, cv=skf, scoring='accuracy', verbose=2, n_jobs=-1)
grid.fit(X_combined, y_combined)

# === En iyi sonuc ===
print("\n[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

# === Test seti uzerinde degerlendirme ===
best_model = grid.best_estimator_
evaluate_model(best_model, X_combined, y_combined, X_val, y_val, X_test, y_test)

# === Modeli kaydet ===
os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)
joblib.dump(best_model, MODEL_SAVE_PATH)
print(f"\n[INFO] Model kaydedildi: {MODEL_SAVE_PATH}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.6s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=0.1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.3s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.5s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=1, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   1.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   1.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   1.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   1.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   0.9s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=10; total time=   1.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   1.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   1.0s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=10; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   1.0s
# [CV] END model__C=10, model__gamma=auto, model__kernel=rbf, pca__n_components=13; total time=   0.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=linear, pca__n_components=13; total time=   1.0s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   1.1s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   1.1s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.9s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   1.0s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   0.9s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   1.0s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=10; total time=   1.1s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   1.0s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.7s
# [CV] END model__C=10, model__gamma=auto, model__kernel=linear, pca__n_components=13; total time=   0.6s
#
# [INFO] En iyi skor: 0.9181047020712185
# [INFO] En iyi parametreler: {'model__C': 10, 'model__gamma': 'scale', 'model__kernel': 'rbf', 'pca__n_components': 13}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 0.5000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.77      0.61      0.68       234
#    PNEUMONIA       0.79      0.89      0.84       390
#
#     accuracy                           0.78       624
#    macro avg       0.78      0.75      0.76       624
# weighted avg       0.78      0.78      0.78       624
#
#
# [INFO] Model kaydedildi: models/dataset1/gridsearch_haralick_svm_balanced_5fold.pkl

# %%
# 📁 model_training_pca_gridsearch.ipynb
# Dataset1'de Combined (HOG + LBP + Haralick) + SVM + PCA + class_weight=balanced + 5-fold CV icin optimize edilmiş versiyon

import os
import numpy as np
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from src.method1.evaluate import evaluate_model
import joblib

# === Combined ozelliklerini yukle ===
X_hog = np.load("features/dataset1/hog/X_train.npy")
X_lbp = np.load("features/dataset1/lbp/X_train.npy")
X_har = np.load("features/dataset1/haralick/X_train.npy")

X_train_combined = np.hstack([X_hog, X_lbp, X_har])

X_hog_val = np.load("features/dataset1/hog/X_val.npy")
X_lbp_val = np.load("features/dataset1/lbp/X_val.npy")
X_har_val = np.load("features/dataset1/haralick/X_val.npy")
X_val_combined = np.hstack([X_hog_val, X_lbp_val, X_har_val])

X_hog_test = np.load("features/dataset1/hog/X_test.npy")
X_lbp_test = np.load("features/dataset1/lbp/X_test.npy")
X_har_test = np.load("features/dataset1/haralick/X_test.npy")
X_test_combined = np.hstack([X_hog_test, X_lbp_test, X_har_test])

# Etiketleri yukle
y_train = np.load("features/dataset1/hog/y_train.npy")
y_val = np.load("features/dataset1/hog/y_val.npy")
y_test = np.load("features/dataset1/hog/y_test.npy")

# === Train + Val birlestir ===
X_combined = np.concatenate([X_train_combined, X_val_combined], axis=0)
y_combined = np.concatenate([y_train, y_val], axis=0)

# === Pipeline tanimi ===
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA()),
    ('model', SVC(class_weight='balanced'))
])

# === Hiperparametre araligi ===
param_grid = {
    'pca__n_components': [100, 200, 300],
    'model__C': [0.1, 1, 10],
    'model__kernel': ['rbf'],
    'model__gamma': ['scale']
}

# === Stratified 5-fold Cross Validation ===
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(pipe, param_grid, cv=skf, scoring='accuracy', verbose=2, n_jobs=-1)
grid.fit(X_combined, y_combined)

# === En iyi sonuc ===
print("\n[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

# === Test seti uzerinde degerlendirme ===
best_model = grid.best_estimator_
evaluate_model(best_model, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)

# === Modeli kaydet ===
MODEL_SAVE_PATH = "models/dataset1/gridsearch_combined_svm_balanced_5fold.pkl"
os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)
joblib.dump(best_model, MODEL_SAVE_PATH)
print(f"\n[INFO] Model kaydedildi: {MODEL_SAVE_PATH}")
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  11.9s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  12.1s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  12.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  12.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  13.1s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  15.7s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  16.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  16.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  12.0s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   8.8s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  16.5s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   8.2s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.9s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  20.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  20.3s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  17.8s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   5.6s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  18.5s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   9.2s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  12.1s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.9s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.9s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  13.7s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  17.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   7.1s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  18.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   8.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   9.1s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  19.5s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  15.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   7.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.8s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  16.3s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  11.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  11.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.7s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  12.2s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  11.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  13.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  14.0s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  12.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=   9.2s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=   8.3s
#
# [INFO] En iyi skor: 0.9873806747599406
# [INFO] En iyi parametreler: {'model__C': 10, 'model__gamma': 'scale', 'model__kernel': 'rbf', 'pca__n_components': 300}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.99      0.36      0.53       234
#    PNEUMONIA       0.72      1.00      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.85      0.68      0.68       624
# weighted avg       0.82      0.76      0.72       624
#
#
# [INFO] Model kaydedildi: models/dataset1/gridsearch_combined_svm_balanced_5fold.pkl

# %%
# 📁 model_training_pca_gridsearch.ipynb
# Dataset1'de Combined (HOG + LBP + Haralick) + SVM + PCA + class_weight=balanced + 5-fold CV icin optimize edilmiş versiyon

import os
import numpy as np
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from src.method1.evaluate import evaluate_model
import joblib

# === Combined ozelliklerini yukle ===
X_hog = np.load("features/dataset1/hog/X_train.npy")
X_lbp = np.load("features/dataset1/lbp/X_train.npy")
X_har = np.load("features/dataset1/haralick/X_train.npy")

X_train_combined = np.hstack([X_hog, X_lbp, X_har])

X_hog_val = np.load("features/dataset1/hog/X_val.npy")
X_lbp_val = np.load("features/dataset1/lbp/X_val.npy")
X_har_val = np.load("features/dataset1/haralick/X_val.npy")
X_val_combined = np.hstack([X_hog_val, X_lbp_val, X_har_val])

X_hog_test = np.load("features/dataset1/hog/X_test.npy")
X_lbp_test = np.load("features/dataset1/lbp/X_test.npy")
X_har_test = np.load("features/dataset1/haralick/X_test.npy")
X_test_combined = np.hstack([X_hog_test, X_lbp_test, X_har_test])

# Etiketleri yukle
y_train = np.load("features/dataset1/hog/y_train.npy")
y_val = np.load("features/dataset1/hog/y_val.npy")
y_test = np.load("features/dataset1/hog/y_test.npy")

# === Train + Val birlestir ===
X_combined = np.concatenate([X_train_combined, X_val_combined], axis=0)
y_combined = np.concatenate([y_train, y_val], axis=0)

# === Pipeline tanimi ===
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA()),
    ('model', SVC(class_weight='balanced'))
])

# === Hiperparametre araligi ===
param_grid = {
    'pca__n_components': [100, 200, 300],
    'model__C': [0.1, 1, 10],
    'model__kernel': ['rbf'],
    'model__gamma': ['scale']
}

# === Stratified 5-fold Cross Validation ===
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(pipe, param_grid, cv=skf, scoring='f1_macro', verbose=2, n_jobs=-1)
grid.fit(X_combined, y_combined)

# === En iyi sonuc ===
print("\n[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

# === Test seti uzerinde degerlendirme ===
best_model = grid.best_estimator_
evaluate_model(best_model, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)

# === Modeli kaydet ===
MODEL_SAVE_PATH = "models/dataset1/gridsearch_combined_svm_balanced_5fold.pkl"
os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)
joblib.dump(best_model, MODEL_SAVE_PATH)
print(f"\n[INFO] Model kaydedildi: {MODEL_SAVE_PATH}")
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  10.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  11.1s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  11.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  11.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=  12.7s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  15.5s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  16.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  16.9s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  11.9s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   8.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.4s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  16.9s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  16.0s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  18.3s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   5.2s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  16.1s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   4.7s
# [CV] END model__C=0.1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  15.7s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   9.7s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   9.5s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.0s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.8s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  11.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   7.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.6s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  15.8s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.8s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  16.8s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  18.4s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  13.7s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   5.7s
# [CV] END model__C=1, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  14.8s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=100; total time=   6.2s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=   9.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  10.2s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=200; total time=  11.1s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  13.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  13.4s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  13.5s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=   8.6s
# [CV] END model__C=10, model__gamma=scale, model__kernel=rbf, pca__n_components=300; total time=  10.7s
#
# [INFO] En iyi skor: 0.9873802965569716
# [INFO] En iyi parametreler: {'model__C': 1, 'model__gamma': 'scale', 'model__kernel': 'rbf', 'pca__n_components': 300}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.98      0.39      0.56       234
#    PNEUMONIA       0.73      0.99      0.84       390
#
#     accuracy                           0.77       624
#    macro avg       0.85      0.69      0.70       624
# weighted avg       0.82      0.77      0.74       624
#
#
# [INFO] Model kaydedildi: models/dataset1/gridsearch_combined_svm_balanced_5fold.pkl

# %%
import os
import numpy as np
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from src.method1.evaluate import evaluate_model
import joblib

# === Combined öznitelikleri yükle ===
X_hog = np.load("features/dataset1/hog/X_train.npy")
X_lbp = np.load("features/dataset1/lbp/X_train.npy")
X_har = np.load("features/dataset1/haralick/X_train.npy")
X_train_combined = np.hstack([X_hog, X_lbp, X_har])

X_hog_val = np.load("features/dataset1/hog/X_val.npy")
X_lbp_val = np.load("features/dataset1/lbp/X_val.npy")
X_har_val = np.load("features/dataset1/haralick/X_val.npy")
X_val_combined = np.hstack([X_hog_val, X_lbp_val, X_har_val])

X_hog_test = np.load("features/dataset1/hog/X_test.npy")
X_lbp_test = np.load("features/dataset1/lbp/X_test.npy")
X_har_test = np.load("features/dataset1/haralick/X_test.npy")
X_test_combined = np.hstack([X_hog_test, X_lbp_test, X_har_test])

# === Etiketleri yükle ===
y_train = np.load("features/dataset1/hog/y_train.npy")
y_val   = np.load("features/dataset1/hog/y_val.npy")
y_test  = np.load("features/dataset1/hog/y_test.npy")

# === Train + Val birleştir ===
X_combined = np.concatenate([X_train_combined, X_val_combined], axis=0)
y_combined = np.concatenate([y_train, y_val], axis=0)

# === Pipeline tanımı ===
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('select', SelectKBest(score_func=f_classif)),
    ('pca', PCA()),
    ('model', MLPClassifier(max_iter=500, random_state=42))
])

# === Hiperparametre aralıkları ===
param_grid = {
    'select__k': [300, 500, 800],
    'pca__n_components': [50, 100, 200],
    'model__hidden_layer_sizes': [(64,), (128,), (128, 64)],
    'model__alpha': [0.0001, 0.001],
    'model__learning_rate_init': [0.001, 0.01]
}

# === 5-fold Stratified CV ===
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(pipe, param_grid, cv=skf, scoring='f1_macro', verbose=2, n_jobs=-1)
grid.fit(X_combined, y_combined)

# === Sonuçlar ===
print("\n[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

# === Test set değerlendirmesi ===
best_model = grid.best_estimator_
evaluate_model(best_model, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)

# === Modeli kaydet ===
MODEL_SAVE_PATH = "models/dataset1/gridsearch_combined_mlp_selectkbest_pca.pkl"
os.makedirs(os.path.dirname(MODEL_SAVE_PATH), exist_ok=True)
joblib.dump(best_model, MODEL_SAVE_PATH)
print(f"\n[INFO] Model kaydedildi: {MODEL_SAVE_PATH}")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   9.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   9.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   9.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   9.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   9.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   9.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   9.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   9.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   4.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   5.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   5.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   5.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   5.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   5.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   5.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   5.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   4.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   4.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   2.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   4.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   4.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   5.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   5.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   5.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   5.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   5.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   5.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   5.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   5.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   4.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   4.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   4.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   5.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   5.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   5.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   1.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   1.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   1.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   1.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   1.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   1.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   1.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   1.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   1.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   1.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   2.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   1.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   1.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   1.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   1.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   1.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   1.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   1.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   1.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   1.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   4.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   2.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   1.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   1.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   1.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   2.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   1.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   3.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   3.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   3.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   3.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   3.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   2.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   4.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   4.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   4.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   3.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   3.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   3.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   3.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   4.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   2.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   2.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   3.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   2.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   1.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   2.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   2.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   3.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   3.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   3.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   3.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   3.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   3.4s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   2.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   3.0s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   2.5s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   2.8s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   2.9s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   2.2s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   2.1s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   2.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   2.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.3s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.7s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.6s
# [CV] END model__alpha=0.0001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   5.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   4.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.1s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   2.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   2.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   2.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.1s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.1s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   2.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   4.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   4.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   4.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   4.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   4.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   4.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   4.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(64,), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   5.0s
# ...
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   4.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   4.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   4.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   4.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.1s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.1s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128,), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   4.1s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=300; total time=   3.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=500; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   3.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=50, select__k=800; total time=   3.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=300; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=500; total time=   3.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=100, select__k=800; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=300; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=500; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   4.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   4.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   3.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   4.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   4.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   3.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.001, pca__n_components=200, select__k=800; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   2.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   4.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   4.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=300; total time=   4.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   5.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   4.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   4.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=500; total time=   4.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   4.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   5.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   4.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   4.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   5.1s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   5.4s[CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=50, select__k=800; total time=   5.3s
#
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   4.4s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   5.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=300; total time=   2.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   5.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   5.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   5.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   5.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=500; total time=   6.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   5.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   6.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=100, select__k=800; total time=   4.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   4.2s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   4.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   4.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   4.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   4.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=300; total time=   5.0s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   2.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   2.8s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   3.3s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=500; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.6s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.5s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.7s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   3.9s
# [CV] END model__alpha=0.001, model__hidden_layer_sizes=(128, 64), model__learning_rate_init=0.01, pca__n_components=200, select__k=800; total time=   2.8s
#
# [INFO] En iyi skor: 0.9791391961878431
# [INFO] En iyi parametreler: {'model__alpha': 0.001, 'model__hidden_layer_sizes': (64,), 'model__learning_rate_init': 0.001, 'pca__n_components': 100, 'select__k': 800}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.97      0.35      0.52       234
#    PNEUMONIA       0.72      0.99      0.83       390
#
#     accuracy                           0.75       624
#    macro avg       0.84      0.67      0.68       624
# weighted avg       0.81      0.75      0.72       624
#
#
# [INFO] Model kaydedildi: models/dataset1/gridsearch_combined_mlp_selectkbest_pca.pkl

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from src.method1.evaluate import evaluate_model

# Pipeline'ı yeniden tanımla
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=3000)),
    ('model', SVC(C=10, kernel='rbf', gamma='scale', class_weight='balanced'))
])

# Eğit ve değerlendir
pipe.fit(X_combined, y_combined)

evaluate_model(pipe, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)
# Out:
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.98      0.39      0.56       234
#    PNEUMONIA       0.73      0.99      0.84       390
#
#     accuracy                           0.77       624
#    macro avg       0.86      0.69      0.70       624
# weighted avg       0.82      0.77      0.74       624

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from src.method1.evaluate import evaluate_model

# Pipeline'ı yeniden tanımla
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', SVC(C=10, kernel='rbf', gamma='scale', class_weight='balanced'))
])

# Eğit ve değerlendir
pipe.fit(X_combined, y_combined)

evaluate_model(pipe, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)
# Out:
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.98      0.40      0.57       234
#    PNEUMONIA       0.73      0.99      0.84       390
#
#     accuracy                           0.77       624
#    macro avg       0.86      0.70      0.70       624
# weighted avg       0.83      0.77      0.74       624

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC

# Pipeline tanımı
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('select', SelectKBest(score_func=f_classif, k=3000)),  # ilk olarak en anlamlı 3000 özniteliği seç
    ('pca', PCA(n_components=500)),                         # ardından PCA ile 500 bileşene indir
    ('model', SVC(kernel='rbf', C=10, gamma='scale', class_weight='balanced'))
])

# Eğit ve değerlendir
pipe.fit(X_combined, y_combined)

evaluate_model(pipe, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)
# Out:
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.95      0.32      0.48       234
#    PNEUMONIA       0.71      0.99      0.83       390
#
#     accuracy                           0.74       624
#    macro avg       0.83      0.66      0.65       624
# weighted avg       0.80      0.74      0.70       624

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from src.method1.evaluate import evaluate_model

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=5000)),
    ('model', SVC(
        kernel='rbf',
        C=10,
        gamma='scale',
        class_weight='balanced'
    ))
])

# Eğit ve değerlendir
pipe.fit(X_combined, y_combined)
evaluate_model(pipe, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)
# Out:
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.98      0.39      0.56       234
#    PNEUMONIA       0.73      0.99      0.84       390
#
#     accuracy                           0.77       624
#    macro avg       0.86      0.69      0.70       624
# weighted avg       0.82      0.77      0.74       624

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.svm import SVC
import joblib

# === Pipeline tanımı ===
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', SVC(kernel='rbf', C=10, gamma='scale', class_weight='balanced'))
])

# === Eğit ve değerlendir ===
pipe.fit(X_combined, y_combined)
evaluate_model(pipe, X_combined, y_combined, X_val_combined, y_val, X_test_combined, y_test)

# === Modeli kaydet ===
joblib.dump(pipe, 'models/dataset1/final_svm_selectk2000.pkl')
print("[INFO] PCA’sız final model kaydedildi: models/dataset1/final_svm_selectk2000.pkl")
# Out:
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.98      0.40      0.57       234
#    PNEUMONIA       0.73      0.99      0.84       390
#
#     accuracy                           0.77       624
#    macro avg       0.86      0.70      0.70       624
# weighted avg       0.83      0.77      0.74       624
#
# [INFO] PCA’sız final model kaydedildi: models/dataset1/final_svm_selectk2000.pkl

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_combined_enc = le.fit_transform(y_combined)
y_val_enc = le.transform(y_val)
y_test_enc = le.transform(y_test)

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.decomposition import PCA
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('select', SelectKBest(score_func=f_classif)),
    ('pca', PCA()),
    ('model', XGBClassifier(eval_metric='mlogloss', random_state=42))
])

param_grid = {
    'select__k': [800, 1000, 1500],
    'pca__n_components': [100, 200, 300],
    'model__n_estimators': [100, 200],
    'model__max_depth': [3, 5],
    'model__learning_rate': [0.01, 0.1],
    'model__subsample': [0.8, 1.0]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(pipe, param_grid, cv=cv, scoring='accuracy', n_jobs=-1, verbose=2)
grid.fit(X_combined, y_combined_enc)

print("\n[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

best_model = grid.best_estimator_
evaluate_model(best_model, X_combined, y_combined_enc, X_val_combined, y_val_enc, X_test_combined, y_test_enc)

import joblib
joblib.dump(best_model, "models/dataset1/final_xgb_selectk_pca_optimized.pkl")
joblib.dump(le, "models/dataset1/final_xgb_label_encoder.pkl")
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   6.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   5.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   6.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   6.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   5.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   5.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   3.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   3.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   5.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   5.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   5.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   3.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   4.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   4.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   5.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   5.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   1.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   5.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   5.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   3.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   4.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   4.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   4.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   4.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   4.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   4.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   4.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   4.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   4.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   4.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   4.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   4.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   4.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   2.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   3.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   4.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   4.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   4.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   3.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   3.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   3.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   2.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   2.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   2.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   3.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   3.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   3.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   5.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   5.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   4.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   7.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   2.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   7.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   7.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   2.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   6.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   6.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   2.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   5.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   5.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   5.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   5.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   5.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   5.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   4.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   4.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   7.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   7.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   6.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   6.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   7.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   5.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   5.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   4.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   4.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   4.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   5.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   6.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   6.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   3.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   2.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   3.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   3.4s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   3.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   3.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   4.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   5.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   5.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   5.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   4.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   5.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   5.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   5.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   4.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   4.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   5.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   7.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   7.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=800; total time=   8.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   6.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   8.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   7.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   6.4s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=   5.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   5.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   8.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   9.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   9.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   9.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=   9.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   3.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   3.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   2.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   3.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   3.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   7.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   7.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   6.4s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=800; total time=   4.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   5.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=   5.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   4.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=   6.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   7.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   8.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   8.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   8.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=800; total time=   8.4s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   8.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   5.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   6.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=   6.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   8.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   8.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   8.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   3.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   8.4s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   6.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   4.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.4s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   4.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   4.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   5.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   6.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   6.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   8.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   8.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   8.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   8.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=   8.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   7.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   7.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   7.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   9.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=   9.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   9.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   9.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=   9.4s
# ...
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   8.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=   9.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  10.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   9.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   7.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  12.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   8.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   7.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=800; total time=   7.8s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  13.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   7.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   8.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   9.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   9.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1000; total time=   9.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   8.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   8.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   8.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   8.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=100, select__k=1500; total time=   7.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=  12.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=  13.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=  13.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=  12.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=  12.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=  11.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=800; total time=  13.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=  11.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=  11.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1000; total time=  15.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=  14.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=  15.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=  17.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=  17.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=200, select__k=1500; total time=  17.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=  19.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=  16.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=  20.8s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=  21.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=800; total time=  20.6s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=  19.8s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=  19.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=  20.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=  16.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1000; total time=  16.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=  10.6s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=  10.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   7.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   6.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=  20.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=800; total time=   7.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   7.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=  21.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=  21.6s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=  21.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=0.8, pca__n_components=300, select__k=1500; total time=  21.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   8.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   9.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   9.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1000; total time=   8.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   9.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   9.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   8.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=   8.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=100, select__k=1500; total time=  10.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=  15.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=  15.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=  15.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=  14.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=800; total time=  15.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=  15.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=  15.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=  12.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=  15.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1000; total time=  15.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=  17.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=  18.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=  18.6s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=  17.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=200, select__k=1500; total time=  17.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=  17.6s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=  20.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=  20.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=  23.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=  23.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=  24.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=800; total time=  24.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=  23.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=  21.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  16.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1000; total time=  17.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  14.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  14.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  14.4s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200, model__subsample=1.0, pca__n_components=300, select__k=1500; total time=  14.6s
#
# [INFO] En iyi skor: 0.9738597856434301
# [INFO] En iyi parametreler: {'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 200, 'model__subsample': 0.8, 'pca__n_components': 100, 'select__k': 1500}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 1.0000
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.34      0.49       234
#            1       0.71      0.97      0.82       390
#
#     accuracy                           0.73       624
#    macro avg       0.79      0.65      0.65       624
# weighted avg       0.77      0.73      0.70       624
# ['models/dataset1/final_xgb_label_encoder.pkl']

# %%
import os, sys
# Proje köküne geç
proj_root = "/Users/nurefsanolfaz/yap470_project/xray_anomaly_method1"
os.chdir(proj_root)
sys.path.insert(0, proj_root)

print("Çalışma dizini:", os.getcwd())

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from src.method1.evaluate import evaluate_model
import joblib
import numpy as np
from sklearn.decomposition import PCA



DATASET = 'dataset1' 
FEATURE_DIR = f"features/{DATASET}/combined"
MODEL_PATH = f"models/{DATASET}/final_knn_combined.pkl"

X_train = np.load(f"{FEATURE_DIR}/X_train.npy")
X_val   = np.load(f"{FEATURE_DIR}/X_val.npy")
X_test  = np.load(f"{FEATURE_DIR}/X_test.npy")
y_train = np.load(f"{FEATURE_DIR}/y_train.npy")
y_val   = np.load(f"{FEATURE_DIR}/y_val.npy")
y_test  = np.load(f"{FEATURE_DIR}/y_test.npy")

# Train + Val birleşimi
X_combined = np.concatenate([X_train, X_val], axis=0)
y_combined = np.concatenate([y_train, y_val], axis=0)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_combined = le.fit_transform(y_combined)
y_val= le.transform(y_val)
y_test = le.transform(y_test)

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=200)),
    ('model', KNeighborsClassifier())
])

param_grid = {
    'model__n_neighbors': [3, 5, 7, 9],
    'model__weights': ['uniform', 'distance'],
    'model__metric': ['euclidean']
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(pipe, param_grid, cv=cv, scoring='f1_macro', verbose=2, n_jobs=-1)
grid.fit(X_combined, y_combined)

print("[INFO] En iyi skor:", grid.best_score_)
print("[INFO] En iyi parametreler:", grid.best_params_)

best_model = grid.best_estimator_

evaluate_model(best_model, X_combined, y_combined, X_val, y_val, X_test, y_test)

# Kaydet
os.makedirs(os.path.dirname(MODEL_PATH), exist_ok=True)
joblib.dump(best_model, MODEL_PATH)
print(f"[INFO] Final KNN modeli kaydedildi: {MODEL_PATH}")
# Out:
# Çalışma dizini: /Users/nurefsanolfaz/yap470_project/xray_anomaly_method1
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=uniform; total time=  25.6s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=distance; total time=  25.7s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=uniform; total time=  25.9s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=uniform; total time=  26.0s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=distance; total time=  26.0s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=distance; total time=  26.1s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=uniform; total time=  26.1s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=uniform; total time=  26.3s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=distance; total time=  20.8s
# [CV] END model__metric=euclidean, model__n_neighbors=3, model__weights=distance; total time=  23.6s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=uniform; total time=  26.4s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=uniform; total time=  26.8s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=distance; total time=  26.8s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=uniform; total time=  27.1s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=uniform; total time=  27.3s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=uniform; total time=  28.9s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=distance; total time=  20.2s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=distance; total time=  27.2s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=distance; total time=  27.0s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=uniform; total time=  27.5s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=uniform; total time=  27.5s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=uniform; total time=  26.9s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=uniform; total time=  28.7s
# [CV] END model__metric=euclidean, model__n_neighbors=5, model__weights=distance; total time=  32.5s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=uniform; total time=  20.9s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=distance; total time=  19.3s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=distance; total time=  19.6s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=distance; total time=  19.8s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=distance; total time=  19.9s
# [CV] END model__metric=euclidean, model__n_neighbors=7, model__weights=distance; total time=  20.5s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=uniform; total time=  21.5s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=uniform; total time=  22.2s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=uniform; total time=  18.6s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=uniform; total time=  16.2s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=uniform; total time=  15.9s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=distance; total time=  16.0s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=distance; total time=  16.2s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=distance; total time=  14.8s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=distance; total time=  14.2s
# [CV] END model__metric=euclidean, model__n_neighbors=9, model__weights=distance; total time=  13.7s
# [INFO] En iyi skor: 0.9764300882526257
# [INFO] En iyi parametreler: {'model__metric': 'euclidean', 'model__n_neighbors': 7, 'model__weights': 'uniform'}
#
# [INFO] Model eğitiliyor...
# [INFO] Validation Accuracy: 0.9375
#
# [INFO] Test set classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.48      0.64       234
#            1       0.76      0.98      0.86       390
#
#     accuracy                           0.79       624
#    macro avg       0.85      0.73      0.75       624
# weighted avg       0.82      0.79      0.77       624
#
# [INFO] Final KNN modeli kaydedildi: models/dataset1/final_knn_combined.pkl
